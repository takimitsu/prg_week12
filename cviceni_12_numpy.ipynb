# %%
import numpy as np

a = np.array([1, 2, 3, 4, 5])

a
# Out:
# array([1, 2, 3, 4, 5])

# %%
np.arange(0, 10, 2)
# Out:
# array([0, 2, 4, 6, 8])

# %%
np.linspace(0, 1, 6)
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. ])

# %%
np.zeros(4)
# Out:
# array([0., 0., 0., 0.])

# %%
np.ones((2, 3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
noise = np.random.normal(loc = 0, scale = .1, size = 8)
np.round(noise, 3)
# Out:
# array([-0.057, -0.128,  0.042, -0.019, -0.106, -0.023, -0.127, -0.161])
